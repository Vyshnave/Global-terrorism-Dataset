# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
data = pd.read_csv('dataset.csv', encoding='ISO-8859-1')
# Out:
# C:\Users\Vyshnave\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region   ...    addnotes scite1 scite2  scite3  \
# 0  Dominican Republic       2   ...         NaN    NaN    NaN     NaN
# 1              Mexico       1   ...         NaN    NaN    NaN     NaN
# 2         Philippines       5   ...         NaN    NaN    NaN     NaN
# 3              Greece       8   ...         NaN    NaN    NaN     NaN
# 4               Japan       4   ...         NaN    NaN    NaN     NaN
#
#    dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.corr()
# Out:
#                  eventid     iyear    imonth      iday  extended   country  \
# eventid         1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear           0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth          0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday            0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended        0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# country        -0.135039 -0.135023 -0.006305  0.003468 -0.020466  1.000000
# region          0.401371  0.401384 -0.002999  0.009710  0.038389  0.148597
# latitude        0.166886  0.166933 -0.015978  0.003423 -0.024749  0.178567
# longitude       0.003907  0.003917 -0.003880 -0.002285  0.000523 -0.000269
# specificity     0.030641  0.030626  0.003621 -0.006991  0.057897 -0.084599
# vicinity        0.070646  0.070659 -0.004501 -0.005367  0.017784 -0.012291
# ...

# %%
fig,ax = plt.subplots(figsize=(25, 15))
sns.heatmap(data.corr(), annot = True, label = 'medium')
plt.show()

# %%
fig,ax = plt.subplots(figsize=(25, 15))
sns.countplot('iyear', data=data,palette = 'inferno')
plt.xticks(rotation = 90)
plt.title('Number of Terrorist Activities based on Year', fontsize = 25)
plt.show()

# %%
sns.pairplot(data, vars=["region", "iyear"], palette="husl")
plt.show()

# %%
missing_data = data.isnull().sum().sort_values(ascending = False)
print(missing_data)
# Out:
# gsubname3           181671
# weapsubtype4_txt    181621
# weapsubtype4        181621
# weaptype4           181618
# weaptype4_txt       181618
# claimmode3          181558
# claimmode3_txt      181558
# gsubname2           181531
# claim3              181373
# guncertain3         181371
# gname3              181367
# divert              181367
# attacktype3         181263
# attacktype3_txt     181263
# ransomnote          181177
# ransompaidus        181139
# ransomamtus         181128
# claimmode2          181075
# claimmode2_txt      181075
# ransompaid          180917
# corp3               180665
# targsubtype3        180594
# targsubtype3_txt    180594
# natlty3             180544
# natlty3_txt         180544
# target3             180516
# targtype3_txt       180515
# targtype3           180515
# ransomamt           180341
# weapsubtype3        179998
#                      ...
# doubtterr                1
# country_txt              0
# region                   0
# ...

# %%
#Dropping columns with more than 20% missing values
missing_20 = missing_data[missing_data > 30000 ]
print(missing_20)
# Out:
# gsubname3           181671
# weapsubtype4_txt    181621
# weapsubtype4        181621
# weaptype4           181618
# weaptype4_txt       181618
# claimmode3          181558
# claimmode3_txt      181558
# gsubname2           181531
# claim3              181373
# guncertain3         181371
# gname3              181367
# divert              181367
# attacktype3         181263
# attacktype3_txt     181263
# ransomnote          181177
# ransompaidus        181139
# ransomamtus         181128
# claimmode2          181075
# claimmode2_txt      181075
# ransompaid          180917
# corp3               180665
# targsubtype3        180594
# targsubtype3_txt    180594
# natlty3             180544
# natlty3_txt         180544
# target3             180516
# targtype3_txt       180515
# targtype3           180515
# ransomamt           180341
# weapsubtype3        179998
#                      ...
# weaptype2_txt       168564
# weaptype2           168564
# nhostkidus          168174
# ...

# %%
data1 = data.drop(missing_20.index , axis = 1)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 47 columns):
# eventid             181691 non-null int64
# iyear               181691 non-null int64
# imonth              181691 non-null int64
# iday                181691 non-null int64
# extended            181691 non-null int64
# country             181691 non-null int64
# country_txt         181691 non-null object
# region              181691 non-null int64
# region_txt          181691 non-null object
# provstate           181270 non-null object
# city                181257 non-null object
# latitude            177135 non-null float64
# longitude           177134 non-null float64
# specificity         181685 non-null float64
# vicinity            181691 non-null int64
# crit1               181691 non-null int64
# crit2               181691 non-null int64
# crit3               181691 non-null int64
# doubtterr           181690 non-null float64
# ...

# %%
fig,ax = plt.subplots(figsize=(25, 15))
sns.heatmap(data1.corr(), annot = True, label = 'medium')
plt.show()

# %%
data1.isnull().sum().sort_values()
# Out:
# eventid                 0
# INT_IDEO                0
# INT_LOG                 0
# dbsource                0
# property                0
# weaptype1_txt           0
# weaptype1               0
# individual              0
# gname                   0
# targtype1_txt           0
# targtype1               0
# INT_MISC                0
# attacktype1             0
# suicide                 0
# success                 0
# crit3                   0
# attacktype1_txt         0
# crit1                   0
# iyear                   0
# imonth                  0
# iday                    0
# extended                0
# country                 0
# country_txt             0
# region                  0
# crit2                   0
# region_txt              0
# INT_ANY                 0
# vicinity                0
# doubtterr               1
# multiple                1
# specificity             6
# ishostkid             178
# guncertain1           380
# provstate             421
# ...

# %%
data_new = data1.dropna(axis = 0)
#dropping missing values

# %%
data_new.isnull().sum()
# Out:
# eventid             0
# iyear               0
# imonth              0
# iday                0
# extended            0
# country             0
# country_txt         0
# region              0
# region_txt          0
# provstate           0
# city                0
# latitude            0
# longitude           0
# specificity         0
# vicinity            0
# crit1               0
# crit2               0
# crit3               0
# doubtterr           0
# multiple            0
# success             0
# suicide             0
# attacktype1         0
# attacktype1_txt     0
# targtype1           0
# targtype1_txt       0
# targsubtype1        0
# targsubtype1_txt    0
# target1             0
# natlty1             0
# natlty1_txt         0
# gname               0
# guncertain1         0
# individual          0
# weaptype1           0
# weaptype1_txt       0
# weapsubtype1        0
# weapsubtype1_txt    0
# nkill               0
# nwound              0
# property            0
# ...

# %%
df = data_new[['extended','country','region','provstate','city','specificity','vicinity','crit1','crit2','crit3', 'multiple','success','suicide','attacktype1','targtype1','natlty1','guncertain1','individual','weaptype1', 'nkill','nwound','property','ishostkid', 'gname']]

# %%
group = df['gname'].value_counts().sort_values(ascending = False)
print(group.shape)
# Out:
# (2775,)

# %%
finalgroup = group[group>50]
finalgroup.shape
# Out:
# (156,)

# %%
finalgroup.index
# Out:
# Index(['Unknown', 'Taliban', 'Islamic State of Iraq and the Levant (ISIL)',
#        'Shining Path (SL)', 'Farabundo Marti National Liberation Front (FMLN)',
#        'Al-Shabaab', 'New People's Army (NPA)',
#        'Kurdistan Workers' Party (PKK)',
#        'Revolutionary Armed Forces of Colombia (FARC)',
#        'Communist Party of India - Maoist (CPI-Maoist)',
#        ...
#        'Paraguayan People's Army (EPP)', 'Bodo Militants',
#        'People's Liberation Front of India', 'Thai Islamic Militants',
#        'Anti-Muslim extremists', 'Terra Lliure',
#        'Democratic Front for the Liberation of Rwanda (FDLR)',
#        'Irish National Liberation Army (INLA)', 'Right-wing extremists',
#        'Communist Party of Nepal - Maoist (CPN-Maoist-Chand)'],
#       dtype='object', length=156)

# %%
df['gname'] = df['gname'].str.replace("'", ' ')
# Out:
# C:\Users\Vyshnave\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
group_1 = df['gname'].value_counts().sort_values(ascending = False)

# %%
final_group_1 = group_1[group_1>100]
print(final_group_1)
# Out:
# Unknown                                                 65513
# Taliban                                                  5407
# Islamic State of Iraq and the Levant (ISIL)              3823
# Shining Path (SL)                                        3283
# Farabundo Marti National Liberation Front (FMLN)         2071
# Al-Shabaab                                               2027
# New People s Army (NPA)                                  2020
# Kurdistan Workers  Party (PKK)                           1731
# Revolutionary Armed Forces of Colombia (FARC)            1694
# Communist Party of India - Maoist (CPI-Maoist)           1562
# Boko Haram                                               1561
# Basque Fatherland and Freedom (ETA)                      1559
# Irish Republican Army (IRA)                              1303
# Liberation Tigers of Tamil Eelam (LTTE)                  1285
# Maoists                                                  1263
# ...

# %%
final_group_1.index
# Out:
# Index(['Unknown', 'Taliban', 'Islamic State of Iraq and the Levant (ISIL)',
#        'Shining Path (SL)', 'Farabundo Marti National Liberation Front (FMLN)',
#        'Al-Shabaab', 'New People s Army (NPA)',
#        'Kurdistan Workers  Party (PKK)',
#        'Revolutionary Armed Forces of Colombia (FARC)',
#        'Communist Party of India - Maoist (CPI-Maoist)', 'Boko Haram',
#        'Basque Fatherland and Freedom (ETA)', 'Irish Republican Army (IRA)',
#        'Liberation Tigers of Tamil Eelam (LTTE)', 'Maoists',
#        'Tehrik-i-Taliban Pakistan (TTP)',
#        'National Liberation Army of Colombia (ELN)',
#        'Al-Qaida in the Arabian Peninsula (AQAP)', 'Palestinians',
#        'Manuel Rodriguez Patriotic Front (FPMR)',
#        'Houthi extremists (Ansar Allah)', 'Al-Qaida in Iraq',
#        'Sikh Extremists', 'Donetsk People s Republic', 'Muslim extremists',
#        'Corsican National Liberation Front (FLNC)', 'Separatists',
# ...

# %%
groupnames = {'Unknown', 'Taliban', 'Islamic State of Iraq and the Levant (ISIL)',
       'Shining Path (SL)', 'Farabundo Marti National Liberation Front (FMLN)',
       'Al-Shabaab', 'New People s Army (NPA)',
       'Kurdistan Workers  Party (PKK)',
       'Revolutionary Armed Forces of Colombia (FARC)',
       'Communist Party of India - Maoist (CPI-Maoist)', 'Boko Haram',
       'Basque Fatherland and Freedom (ETA)', 'Irish Republican Army (IRA)',
       'Liberation Tigers of Tamil Eelam (LTTE)', 'Maoists',
       'Tehrik-i-Taliban Pakistan (TTP)',
       'National Liberation Army of Colombia (ELN)',
       'Al-Qaida in the Arabian Peninsula (AQAP)', 'Palestinians',
       'Manuel Rodriguez Patriotic Front (FPMR)',
       'Houthi extremists (Ansar Allah)', 'Al-Qaida in Iraq',
       'Sikh Extremists', 'Donetsk People s Republic', 'Muslim extremists',
       'Corsican National Liberation Front (FLNC)', 'Separatists',
       'Tupac Amaru Revolutionary Movement (MRTA)',
       'African National Congress (South Africa)', 'Abu Sayyaf Group (ASG)',
       'Palestinian Extremists', 'Sinai Province of the Islamic State',
       'People s Liberation Front (JVP)', 'Narco-Terrorists',
       'Hamas (Islamic Resistance Movement)',
       'Nicaraguan Democratic Force (FDN)',
       'Bangsamoro Islamic Freedom Movement (BIFM)',
       'National Union for the Total Independence of Angola (UNITA)',
       'M-19 (Movement of April 19)', 'Baloch Republican Army (BRA)',
       'United Liberation Front of Assam (ULFA)', 'Hezbollah',
       'Khorasan Chapter of the Islamic State', 'Chechen Rebels',
       'Moro Islamic Liberation Front (MILF)', 'Gunmen', 'Death Squad',
       'Fulani extremists', 'Mozambique National Resistance Movement (MNR)',
       'Al-Gama at al-Islamiyya (IG)',
       'Al-Qaida in the Islamic Maghreb (AQIM)', 'Dev Sol',
       'Hizbul Mujahideen (HM)', 'Anti-Abortion extremists',
       'Nicaraguan Resistance', 'Lashkar-e-Taiba (LeT)',
       'Popular Liberation Army (EPL)', 'Armed Islamic Group (GIA)',
       'Baloch Liberation Front (BLF)',
       'Tripoli Province of the Islamic State',
       'First of October Antifascist Resistance Group (GRAPO)',
       'Left-Wing Militants',
       'Salafist Group for Preaching and Fighting (GSPC)',
       'Baloch Liberation Army (BLA)', 'Luhansk People s Republic',
       'Muslim Militants', 'Simon Bolivar Guerrilla Coordinating Board (CGSB)',
       'Red Brigades', 'Palestinian Islamic Jihad (PIJ)',
       'Movement of the Revolutionary Left (MIR) (Chile)',
       'Garo National Liberation Army', 'Al-Aqsa Martyrs Brigade',
       'Moro National Liberation Front (MNLF)',
       'National Democratic Front of Bodoland (NDFB)', 'Lashkar-e-Jhangvi',
       'Runda Kumpulan Kecil (RKK)', 'Al-Nusrah Front',
       'Islamic State of Iraq (ISI)',
       'Palestine Liberation Organization (PLO)',
       'Allied Democratic Forces (ADF)', 'Islamist extremists',
       'Islamic Salvation Front (FIS)',
       'Armenian Secret Army for the Liberation of Armenia', 'Tamils',
       'Lord s Resistance Army (LRA)', 'Barqa Province of the Islamic State',
       'Muttahida Qami Movement (MQM)',
       'Popular Front for the Liberation of Palestine (PFLP)',
       'November 17 Revolutionary Organization (N17RO)',
       'People s Liberation Forces (FPL)',
       'Corsican National Liberation Front- Historic Channel', 'Janjaweed',
       'Free Aceh Movement (GAM)'}

# %%
df_final = df.loc[df['gname'].isin(groupnames)]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117550 entries, 7 to 181689
# Data columns (total 24 columns):
# extended       117550 non-null int64
# country        117550 non-null int64
# region         117550 non-null int64
# provstate      117550 non-null object
# city           117550 non-null object
# specificity    117550 non-null float64
# vicinity       117550 non-null int64
# crit1          117550 non-null int64
# crit2          117550 non-null int64
# crit3          117550 non-null int64
# multiple       117550 non-null float64
# success        117550 non-null int64
# suicide        117550 non-null int64
# attacktype1    117550 non-null int64
# targtype1      117550 non-null int64
# natlty1        117550 non-null float64
# guncertain1    117550 non-null float64
# individual     117550 non-null int64
# weaptype1      117550 non-null int64
# nkill          117550 non-null float64
# nwound         117550 non-null float64
# property       117550 non-null int64
# ...

# %%
df_final.corr()
# Out:
#              extended   country    region  specificity  vicinity     crit1  \
# extended     1.000000 -0.020845 -0.008781     0.032257  0.021185 -0.018677
# country     -0.020845  1.000000  0.142116    -0.076421 -0.004524 -0.019277
# region      -0.008781  0.142116  1.000000    -0.085333  0.062417  0.029792
# specificity  0.032257 -0.076421 -0.085333     1.000000 -0.058221  0.016171
# vicinity     0.021185 -0.004524  0.062417    -0.058221  1.000000  0.003856
# crit1       -0.018677 -0.019277  0.029792     0.016171  0.003856  1.000000
# crit2       -0.000329 -0.015094 -0.010797     0.006166 -0.004461 -0.008141
# crit3        0.034051 -0.037609  0.008369    -0.075425 -0.053535 -0.044670
# multiple    -0.027171 -0.016412  0.005950     0.036894 -0.011098  0.031480
# success      0.045555 -0.061471 -0.007141     0.017976 -0.002325 -0.005239
# suicide     -0.025325 -0.059002  0.117719    -0.020982  0.004348  0.023393
# ...

# %%
fig,ax = plt.subplots(figsize=(25, 15))
sns.heatmap(df_final.corr(), annot = True, label = 'medium')
plt.show()

# %%
df_final['gname'].value_counts().head()
# Out:
# Unknown                                             65513
# Taliban                                              5407
# Islamic State of Iraq and the Levant (ISIL)          3823
# Shining Path (SL)                                    3283
# Farabundo Marti National Liberation Front (FMLN)     2071
# Name: gname, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
df_final['newy'] = labelencoder.fit_transform(df_final['gname'])
# Out:
# C:\Users\Vyshnave\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
text_cols = df_final.select_dtypes(include=['object']).columns
print(text_cols)
# Out:
# Index(['provstate', 'city', 'gname'], dtype='object')

# %%
df_final['newcity'] = labelencoder.fit_transform(df_final['city'])
df_final['newprovstate'] = labelencoder.fit_transform(df_final['provstate'])
# Out:
# C:\Users\Vyshnave\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Vyshnave\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
df_final = df_final.drop(['city', 'provstate'] ,axis = 1)

# %%
df_final['y2'] = df_final['newy']
df_final = df_final.drop(['gname' , 'newy'] ,axis = 1)

# %%
X = df_final.iloc[:, 0:23].values
y  = df_final.iloc[:, 23].values

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values = 'NaN', strategy = 'mean', axis=0)
imputer = imputer.fit(X)
X = imputer.transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test , y_train , y_test = train_test_split(X, y , test_size=0.2, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier1 = RandomForestClassifier(random_state = 42)
classifierslist = [classifier1]
acclist = []

# %%
for classifier in classifierslist:
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)  
    from sklearn.metrics import accuracy_score
    acc = accuracy_score(y_test, y_pred)
    from sklearn.metrics import f1_score
    f1 = f1_score(y_test, y_pred, average=None)
    acclist.append(acc)
    print(acc)
# Out:
# 0.7616758826031476

# %%
print(f1)
# Out:
# [0.65753425 0.61458333 0.25531915 0.62222222 0.26666667 0.32
#  0.71044776 0.1754386  0.79034307 0.54545455 0.875      0.39285714
#  0.21621622 0.13636364 0.22222222 0.15584416 0.6259542  0.28571429
#  0.87256372 0.8822606  0.5952381  0.74528302 0.63694268 0.66666667
#  0.57692308 0.43835616 0.72477064 0.84702908 0.55172414 0.69565217
#  0.63529412 0.38888889 0.24657534 0.33333333 0.40384615 0.16
#  0.71428571 0.86178862 0.47058824 0.24       0.5704023  0.13793103
#  0.23076923 0.19047619 0.83506686 0.28571429 0.16666667 0.78787879
#  0.81886792 0.65116279 0.41176471 0.336      0.54183267 0.63473054
#  0.2739726  0.33333333 0.29268293 0.86046512 0.11764706 0.25174825
#  0.72222222 0.53658537 0.43137255 0.47482014 0.89430894 0.79372738
#  0.77241379 0.40677966 0.47368421 0.52941176 0.68674699 0.
#  0.56677524 0.06896552 0.63716814 0.         0.14545455 0.60714286
#  0.63967611 0.66666667 0.3        0.37209302 0.85410765 0.48514851
# ...

# %%
from sklearn.metrics import classification_report
clsf_rprt = classification_report(y_test, y_pred)

# %%
print(clsf_rprt)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.72      0.61      0.66        79
#           1       0.65      0.58      0.61       101
#           2       0.27      0.24      0.26        25
#           3       0.65      0.60      0.62        47
#           4       0.50      0.18      0.27        33
#           5       0.42      0.26      0.32       123
#           6       0.70      0.73      0.71       164
#           7       0.33      0.12      0.18        42
#           8       0.75      0.84      0.79       370
#           9       0.60      0.50      0.55        18
#          10       0.93      0.82      0.87        34
#          11       0.52      0.31      0.39        35
#          12       0.50      0.14      0.22        29
#          13       0.18      0.11      0.14        27
#          14       0.30      0.18      0.22        34
#          15       0.22      0.12      0.16        50
#          16       0.68      0.58      0.63        71
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn import metrics
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10, scoring = 'accuracy')

# %%
print(accuracies.mean())
print(accuracies.std())
# Out:
# 0.7609109773939975
# 0.0034936476086390397
